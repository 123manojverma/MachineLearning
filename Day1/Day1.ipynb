# %% [markdown]
# ![image.png](attachment:9e97c816-f8ad-4d07-8575-298f57c2ce55.png)

# %%
# Single Line Comment 
# '''''' Multi Line Comment

#Python is Case Sensitive
name="AJ"
Name="AK"
print(name)
print(Name)
# Out:
# AJ
# AK

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Indentation 
## Python uses indentation o define blocks of code. Consistent use of spaces (commonly 4) or a tab is required.

age=32
if age>30:
    print(age)
print(age)
# Out:
# 32
# 32

# %%
## This is a single line comment
print("Hello world")
# Out:
# Hello world

# %%
## Line Continuation 
total=1+2+3+4+5+6+\
    4+5+6
print(total)
# Out:
# 36

# %%
## Multiple Statements on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
## Understand semantics in Python 
# Variable assignment
age=32 ##age is an integer
name="Krish" # name is a string
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
# Type inference
variable =10
print(type(variable))
variable="Krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=32
if age>30:
    print(age)
# Out:
# 32

# %%
# Code examples of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This out print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block

# %% [markdown]
# # Variables

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=100

# %%
# Declaring and Assigning Variables

age=20
name="Manoj"
is_student=True

# printing the variables

print("age : ",age)
print("name : ",name)
# Out:
# age :  20
# name :  Manoj

# %%
# Naming Conventions
# Variable names should be descriptive
# They must start with a letter or an '_' and contains letter,numbers and underscores
# Variables names case sensitive 

# valid variable names

first_name="MAnoj"

# %%
# understanding variable types
# Python is dynamically typed, type of a variable is determined at runtime
age=20 # int
height=5.8 # float
name="Manoj" # str
is_student=True # bool
print(type(name))
# Out:
# <class 'str'>

# %%
# Type Checking and Conversion
type(height)
# Out:
# float

# %%
age=25
print(type(age))

#Type Conversion
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name="Manoj"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 name="Manoj"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Manoj'

# %%
height=5.11
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 5.0

# %%
# Dynamic Typing
# Python allows the type of a variable to change as the program executes

var=10 #int
print(var,type(var))

var="Hello" #str
print(var,type(var))

var=3.14 #float
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
# input
age=input("What is the age")
print(age,type(age))
# Out:
# 52 <class 'str'>

# %%
# Simple Calculator
num1=float(input("Enter first number: "))
num2=float(input("Enter second number: "))

sum=num1+num2
difference=num1-num2
product=num1*num2
quotient=num1/num2

print(sum)
print(difference)
print(product)
print(quotient)
# Out:
# 64.0
# 40.0
# 624.0
# 4.333333333333333

# %% [markdown]
# # Data Types

# %%
# int float string
a=10
b=5.6
c="hello"
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
bool()
# Out:
# False

# %%
a=10
b=10
type(a==b)
# Out:
# bool

# %%
# common errors
result="Hello"+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # common errors
# ----> 2 result="Hello"+5
#
# TypeError: can only concatenate str (not "int") to str

# %%
result="Hello"+str(5)
print(result)
# Out:
# Hello5

# %% [markdown]
# # Operators

# %%
# Arithmetic Operations

a=12
b=5
add_result=a+b   #addition
sub_result=a-b   #subtraction
multi_result=a*b #multiplication
div_result=a/b   #division
floor_result=a//b #floor division
modulus_result=a%b #modulus operation
exponent_result=a**b #Exponentiation
print(add_result)
print(sub_result)
print(multi_result)
print(div_result)
print(floor_result)
print(modulus_result)
print(exponent_result)
# Out:
# 17
# 7
# 60
# 2.4
# 2
# 2
# 248832

# %%
# Comparision Operators
# == Equal to 
a=10
b=10

a==b
# Out:
# True

# %%
str1="Krish"
str2="Krish"
str1==str2
# Out:
# True

# %%
# Not Equal to !=
str1!=str2
# Out:
# False

# %%
str3="Krish"
str4="krish"

str3!=str4
# Out:
# True

# %%
# greater than 
num1=45
num2=55
num1>num2
# Out:
# False

# %%
# less than <
num1<num2
# Out:
# True

# %%
# greater than or equal to 
num1=45
num2=45
num1>=num2
# Out:
# True

# %%
# less than or equal to 
num1=44
num2=45
num1<=num2
# Out:
# True

# %%
# Logical Operators
# and

x=True
y=False
result=x and y
print(result)
# Out:
# False

# %%
# or

x=True
y=False
result=x or y
print(result)
# Out:
# True

# %%
# not operator

x=True
print(not x)
# Out:
# False
