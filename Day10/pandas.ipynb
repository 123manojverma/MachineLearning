# %% [markdown]
# # Pandas - DataFrame and Series
#
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogenous tabular data structure with labeled axes (rows and columns).

# %%
# Series 
# A Pandas Series is a one-dimensional array-like object that can hold any data type. It is similar to a column in a table.

import pandas as pd
data=[1,2,3,4,5]
series=pd.Series(data)
print("Series \n",series)
print(type(series))
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# Create a Series from dictionary
dict={'a':1,'b':2,'c':3}
series_dict=pd.Series(dict)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[10,20,30]
index=['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# Dataframe
# create a Dataframe from a dictionary of list

data={
    'Name':['Krish','John','Jack'],
    'Age':[25,30,40],
    'City':['Bangalore','New York','Florida']
}
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   40    Florida
# <class 'pandas.core.frame.DataFrame'>

# %%
# Create a Data frame from a list of dictionaries
data=[
    {'Name':'Krish','Age':35,'City':'Bangalore'},
    {'Name':'Peter','Age':30,'City':'New York'},
    {'Name':'Jack','Age':45,'City':'Las Vegas'},
    {'Name':'John','Age':39,'City':'Mumbai'}
]

df1=pd.DataFrame(data)
print(df1)
print(type(df1))
# Out:
#     Name  Age       City
# 0  Krish   35  Bangalore
# 1  Peter   30   New York
# 2   Jack   45  Las Vegas
# 3   John   39     Mumbai
# <class 'pandas.core.frame.DataFrame'>

# %%
df=pd.read_csv('sales_data.csv')
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       NaN              Yu             Kwai    Small
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France      EMEA        Da Cunha           Daniel   Medium
# 3      90003     USA       NaN           Young            Julie   Medium
# 4        NaN     USA       NaN           Brown            Julie   Medium
#
# [5 rows x 25 columns]

# %%
df.tail(5)
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 68        10275               22     100.00                4  2904.44
# 69        10285               47     100.00                9  6484.59
# 70        10298               39      96.34                1  3757.26
# 71        10308               34     100.00                2  4043.96
# 72        10318               45     100.00                4  5566.50
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 68   7/23/2004 0:00  Shipped       3         7     2004  ...
# 69   8/27/2004 0:00  Shipped       3         8     2004  ...
# 70   9/27/2004 0:00  Shipped       3         9     2004  ...
# 71  10/15/2004 0:00  Shipped       4        10     2004  ...
# 72   11/2/2004 0:00  Shipped       4        11     2004  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2          CITY STATE POSTALCODE  \
# 68  67, rue des Cinquante Otages           NaN        Nantes   NaN      44000
# 69           39323 Spinnaker Dr.           NaN     Cambridge    MA      51247
# 70                54, rue Royale           NaN        Nantes   NaN      44000
# 71     3758 North Pendale Street           NaN  White Plains    NY      24067
# 72              7586 Pompton St.           NaN     Allentown    PA      70267
#
#    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 68  France      EMEA         Labrune           Janine    Small
# 69     USA       NaN       Hernandez            Marta   Medium
# 70  France      EMEA         Schmitt           Carine   Medium
# 71     USA       NaN           Frick            Steve   Medium
# 72     USA       NaN              Yu            Kyung   Medium
#
# [5 rows x 25 columns]

# %%
# Accessing data from dataframe
df1
# Out:
#     Name  Age       City
# 0  Krish   35  Bangalore
# 1  Peter   30   New York
# 2   Jack   45  Las Vegas
# 3   John   39     Mumbai

# %%
df1['Name']
# Out:
# 0    Krish
# 1    Peter
# 2     Jack
# 3     John
# Name: Name, dtype: object

# %%
type(df1['Name'])
# Out:
# pandas.core.series.Series

# %%
# loc means label based 
df1.loc[0]
# Out:
# Name        Krish
# Age            35
# City    Bangalore
# Name: 0, dtype: object

# %%
# integer position based indexing 
df1.iloc[0]
# Out:
# Name        Krish
# Age            35
# City    Bangalore
# Name: 0, dtype: object

# %%
df1.iloc[0][2]
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_81376\1028912939.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df1.iloc[0][2]
# 'Bangalore'

# %%
df1
# Out:
#     Name  Age       City
# 0  Krish   35  Bangalore
# 1  Peter   30   New York
# 2   Jack   45  Las Vegas
# 3   John   39     Mumbai

# %%
# Accessing a specified element
df1.at[1,'Age']
# Out:
# np.int64(30)

# %%
df1.at[2,'Name']
# Out:
# 'Jack'

# %%
# Accessing a specified element using iat
df1.iat[2,2]
# Out:
# 'Las Vegas'

# %%
# Data Manipulation with Dataframe
df1
# Out:
#     Name  Age       City
# 0  Krish   35  Bangalore
# 1  Peter   30   New York
# 2   Jack   45  Las Vegas
# 3   John   39     Mumbai

# %%
df1['Salary']=[50000,60000,70000,80000]
df1
# Out:
#     Name  Age       City  Salary
# 0  Krish   35  Bangalore   50000
# 1  Peter   30   New York   60000
# 2   Jack   45  Las Vegas   70000
# 3   John   39     Mumbai   80000

# %%
# Remove a column 
df1.drop('Salary',axis=1)
# Out:
#     Name  Age       City
# 0  Krish   35  Bangalore
# 1  Peter   30   New York
# 2   Jack   45  Las Vegas
# 3   John   39     Mumbai

# %%
df1
# Out:
#     Name  Age       City  Salary
# 0  Krish   35  Bangalore   50000
# 1  Peter   30   New York   60000
# 2   Jack   45  Las Vegas   70000
# 3   John   39     Mumbai   80000

# %%
df1.drop('Salary',axis=1,inplace=True) # To delete permanently

# %%
df1
# Out:
#     Name  Age       City
# 0  Krish   35  Bangalore
# 1  Peter   30   New York
# 2   Jack   45  Las Vegas
# 3   John   39     Mumbai

# %%
# Add age to the column
df1['Age']=df1['Age']+1
df1
# Out:
#     Name  Age       City
# 0  Krish   36  Bangalore
# 1  Peter   31   New York
# 2   Jack   46  Las Vegas
# 3   John   40     Mumbai

# %%
df1.drop(0,inplace=True)
df1
# Out:
#     Name  Age       City
# 1  Peter   31   New York
# 2   Jack   46  Las Vegas
# 3   John   40     Mumbai

# %%
# Display the data types of each column
print("Data types:\n",df.dtypes)

# Describe the Dataframe
print("Statistical summary:\n",df.describe())

# Group by a column and perform an aggregation
# grouped=df.groupby('Category')['Value'].mean()
# print("Mean value by category:\n",grouped)
# Out:
# Data types:
#  ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object
# Statistical summary:
#          ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER  \
# count     73.000000        73.000000   73.000000        73.000000
# mean   10247.205479        35.178082   97.215479         5.493151
# std       89.024647         9.394653    9.115088         3.969058
# min    10103.000000        20.000000   34.910000         1.000000
# 25%    10174.000000        27.000000  100.000000         2.000000
# 50%    10245.000000        36.000000  100.000000         5.000000
# 75%    10312.000000        42.000000  100.000000         9.000000
# max    10424.000000        66.000000  100.000000        17.000000
#
#               SALES     QTR_ID   MONTH_ID      YEAR_ID        MSRP
# count     73.000000  73.000000  73.000000    73.000000   73.000000
# mean    5036.988082   2.767123   7.191781  2003.739726  146.630137
# std     2338.431073   1.172847   3.561591     0.667237   54.258258
# min      733.110000   1.000000   1.000000  2003.000000   95.000000
# 25%     3307.770000   2.000000   4.000000  2003.000000   95.000000
# 50%     4472.000000   3.000000   8.000000  2004.000000  118.000000
# 75%     6120.340000   4.000000  11.000000  2004.000000  214.000000
# max    12001.000000   4.000000  12.000000  2005.000000  214.000000

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER  \
# count     73.000000        73.000000   73.000000        73.000000
# mean   10247.205479        35.178082   97.215479         5.493151
# std       89.024647         9.394653    9.115088         3.969058
# min    10103.000000        20.000000   34.910000         1.000000
# 25%    10174.000000        27.000000  100.000000         2.000000
# 50%    10245.000000        36.000000  100.000000         5.000000
# 75%    10312.000000        42.000000  100.000000         9.000000
# max    10424.000000        66.000000  100.000000        17.000000
#
#               SALES     QTR_ID   MONTH_ID      YEAR_ID        MSRP
# count     73.000000  73.000000  73.000000    73.000000   73.000000
# mean    5036.988082   2.767123   7.191781  2003.739726  146.630137
# std     2338.431073   1.172847   3.561591     0.667237   54.258258
# min      733.110000   1.000000   1.000000  2003.000000   95.000000
# 25%     3307.770000   2.000000   4.000000  2003.000000   95.000000
# 50%     4472.000000   3.000000   8.000000  2004.000000  118.000000
# 75%     6120.340000   4.000000  11.000000  2004.000000  214.000000
# max    12001.000000   4.000000  12.000000  2005.000000  214.000000
